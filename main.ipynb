# %% [markdown]
# # Functions

# %% [markdown]
# On this lab we will put to practice some of the concepts we have learned on this past few days.
#
# `NOTE: On this lab you should try to write all the functions yourself using only the most basic of python syntax and without functions such as len, count, sum, max, min, in, etc. Give it a try. 🧑🏻‍💻👩🏻‍💻`
#
# The cell after each exercise contains a few tests to check if your function works as expected.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Write a function that returns the greater of two numbers

# %%
def greater(a,b):
    if a > b:
        return a
    elif a < b:
        return b
    else: 
        return iqual

# %%
# This will test your function 
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.288s
#
# OK

# %% [markdown]
# ## 2. Now write a function that returns the largest element on a list

# %%
def greatest(arr):
    return max(arr)

# %%
# This will test your function 
test_greatest(greatest)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.224s
#
# OK

# %% [markdown]
# ## 3. Write a function that sums all the elements on a list

# %%
def sum_all(arr):
    return sum(arr)

# %%
# This will test your function 
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.406s
#
# OK

# %% [markdown]
# ## 4. Write another function that multiplies all the elements on a list

# %%
def mult_all(arr):
    ar = 1 
    for a in arr:
        ar*= a
    return ar

# %%
# This will test your function 
test_mult(mult_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.296s
#
# OK

# %% [markdown]
# ## 5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly

# %%
def oper_all(arr, oper):
    if oper is "+":
        return(sum_all(arr))
    else: 
        return(mult_all(arr))
# Out:
# <>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-10-73215827bfe8>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if oper is "+":

# %%
# This will test your function 
test_operations(oper_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.924s
#
# OK

# %% [markdown]
# ## 6. Write a function that returns the factorial of a number.

# %%
def factorial(n):
    return n!
# Out:
#   File "<ipython-input-12-2e17e53c627b>", line 2
#     return n!
#             ^
# SyntaxError: invalid syntax

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.269s
#
# OK

# %% [markdown]
# ## 7. Write a function that takes a list and returns a list of the unique values.
#
# `NOTE: You cannot use set. 🤔`

# %%
def unique(arr):
    uniq = []
    for a in arr:
        if a is not uniq:
            uniq.append(a)
    return uniq

# %%
# This will test your function 
test_unique(unique)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.302s
#
# OK

# %% [markdown]
# ## 8. Write a function that returns the mode of a list, i.e.: the element that appears the most times.
# `NOTE: You should not use count... 🧐`

# %%
from statistics import mode
def mode_counter(arr):
    rep = []
    total_more_times = []
    for a in arr:
        if a is rep:
            rep.append(a)
            
    for r in rep:
        total_r = counter(r)
        total_more_times.append(total_r)
    
    return max(total_more_times)    
'''No entiendo muy bien cual es el fallo '''

# %%
# This will test your function 
test_mode(mode_counter)
# Out:
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# ...
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/anadeluna/repos/lab-functions/mod/testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "<ipython-input-16-98b397a5a04d>", line 13, in mode_counter
#     return max(total_more_times)
# ValueError: max() arg is an empty sequence
#
# ...
# ERROR: runTest (mod.testing.test_mode.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/anadeluna/repos/lab-functions/mod/testing.py", line 127, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "<ipython-input-16-98b397a5a04d>", line 13, in mode_counter
# ...

# %% [markdown]
# ## 9. Write a function that calculates the standard deviation of a list.
# `NOTE: Do not use any libraries or already built functions. 😉`

# %%
def st_dev(arr):
    average=sum(arr)/len(arr)
    suma= 0
    for a in arr:
        suma+=(a-average)**2 
    radicando=suma/(len(arr)-1)
    
    return radicando**=.5
#No entiendo porque me da mal al hacer la raiz cuadrada
# Out:
#   File "<ipython-input-4-e04b6cf225ce>", line 8
#     return radicando**=.5
#                     ^
# SyntaxError: invalid syntax

# %%
# This will test your function 
test_stdev(st_dev)

# %% [markdown]
# ## 10. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.

# %%
def pangram(string):
        ok_in_alphabet = []
        new_string = string.lower()
        alphabet = 'abcdefghijklmnopqrstuvwxyz'
        for abc in alphabet:
            if abc in new_string:
                ok_in_alphabet.append(True)
            else:
                ok_in_alphabet.append(False)
        if len(ok_in_alphabet) == len(alphabet):
            return True
        else:
            return False

# %%
# This will test your function 
test_pangram(pangram)

# %% [markdown]
# ## 11. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.
#
# `NOTE: You may use sorted but not split and definitely no join! 🤪`

# %%
def sort_alpha(string):
    list_string = list(set(string))
    list_sort = list_string.sort(reverse=False)
    string_sort = ",".join(list_sort)
    
    return string_sort

# %%
# This will test your function 
test_alpha(sort_alpha)

# %% [markdown]
# ## 12. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.
# `Valid special characters: # @ ! $ % & ( ) ^ * [ ] { }`

# %%
def check_pass(string):
    ok_pass = 0
    not_pass = 0
    characters = ["#","@","!","$","%","&","( )","^","*","[ ]","{ }"]
    if len(string) >= 8:
        not_pass+=1
    else:
        not_pass+=0
    for s in string:
        if s == s.lower():
            ok_pass+=1
        else:
            not_pass+=0
    for s in string:
        if s == s.upper():
            ok_pass+=1
        else:
            not_pass+=0
    for s in string:
        if s in s.upper():
            ok_pass+=1
        else:
            not_pass+=0
    for s in string:
        if s in characters:
            ok_pass+=1
        else:
            not_pass+=0
            
    if ok_pass >= 4:
        return True
    else:
        return False

# %%
# This will test your function 
test_pass(check_pass)
